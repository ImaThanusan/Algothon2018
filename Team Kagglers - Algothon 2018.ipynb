# %% [markdown]
# # Predicting Stock Movement Using Market Sentiments

# %% [markdown]
# ## Questions:
# ### (1) Based on stock price data can you predict whether tomorrow's Closing Price is greater/less than today's closing price?
# ### (2) What influence does social media sentiment data have on prediction?
# ### (3) How long in the past is data relevant?

# %% [markdown]
# ## Stock Chosen: Nike
#
# ### (1) Clothing Industry
# ### (2) Social Media Presence

# %% [markdown]
# #### A notebook by Seema, Thanusan, Adit & Sean

# %% [markdown]
# ### Import Libraries

# %%
import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.optimizers import Adam
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Import Sentiments Data and Feature Engineering

# %% [markdown]
# #### News Sentiment

# %%
quandl.ApiConfig.api_key = '-fujnELuC1_ZZSKPzix8'

news_sentiments_raw = quandl.get_table('IFT/NSA', ticker='NKE')
mask = news_sentiments_raw["exchange_cd"] == "US"

news_sentiments = news_sentiments_raw[mask]
news_sentiments = news_sentiments.set_index('date')

#Getting rid of irrelevant columns
news_sentiments = news_sentiments.drop(['exchange_cd', 'name'], axis=1)

# %%
no_rows_news = news_sentiments.shape[0]
no_columns_news = news_sentiments.shape[1]
print('The dimension of the Nike News Sentiments DataFrame is %s by %s' % (no_rows_news, no_columns_news))
# Out:
# The dimension of the Nike News Sentiments DataFrame is 2119 by 6

# %%
news_sentiments.head(5)
# Out:
#            ticker  sentiment  sentiment_high  sentiment_low  news_volume  \
# date
# 2018-07-20    NKE      1.444           3.899         -2.010            9
# 2018-07-21    NKE      2.000           2.000          2.000            1
# 2018-07-22    NKE      2.000           3.000          1.000            2
# 2018-07-23    NKE      3.333           3.805          2.862            3
# 2018-07-24    NKE      3.333           4.581          2.086            3
#
#             news_buzz
# date
# 2018-07-20       10.0
# 2018-07-21        6.0
# 2018-07-22        6.0
# 2018-07-23       10.0
# 2018-07-24        5.0

# %% [markdown]
# #### Facebook Sentiment

# %%
facebook_sentiment = quandl.get_table('SMA/FBUP', brand_ticker='NKE', paginate=True)
facebook_sentiment = facebook_sentiment.set_index('date')

cols_to_drop = ['brand_ticker', 'page_id', 'post_id', 'sector', 'geography', 'type', 'created_time', 'response_time', 'likes', 'comments', 'shares']

# Getting rid of irrelevant columns
facebook_sentiment = facebook_sentiment.drop(cols_to_drop, axis=1)
facebook_sentiment.columns = ['FB_sentiment']

no_rows_FB = facebook_sentiment.shape[0]
no_columns_FB = facebook_sentiment.shape[1]
print('The dimension of the Nike News Sentiments DataFrame is %s by %s' % (no_rows_FB, no_columns_FB))
# Out:
# The dimension of the Nike News Sentiments DataFrame is 126010 by 1

# %%
facebook_sentiment.sort_index(inplace = True)
facebook_sentiment.head(5)
# Out:
#            FB_sentiment
# date
# 2014-01-01      NEUTRAL
# 2014-01-01      NEUTRAL
# 2014-01-01      NEUTRAL
# 2014-01-01      NEUTRAL
# 2014-01-01      NEUTRAL

# %% [markdown]
# #### Instagram Sentiment

# %%
insta_sentiment = quandl.get_table('SMA/INSD', brand_ticker='NKE', paginate=True)

nike_mask = insta_sentiment['ins_account_name'] == 'nike'

insta_sentiment = insta_sentiment[nike_mask]

insta_sentiment = insta_sentiment.set_index('date')
insta_sentiment.sort_index(inplace = True)

# %%
insta_sentiment.head(n=20)
# Out:
#            brand_ticker ins_account_name brand_name  sector  geography  \
# date
# 2014-01-01          NKE             nike       nike  Retail  Worldwide
# 2014-01-02          NKE             nike       nike  Retail  Worldwide
# 2014-01-03          NKE             nike       nike  Retail  Worldwide
# 2014-01-04          NKE             nike       nike  Retail  Worldwide
# 2014-01-05          NKE             nike       nike  Retail  Worldwide
# 2014-01-06          NKE             nike       nike  Retail  Worldwide
# 2014-01-07          NKE             nike       nike  Retail  Worldwide
# 2014-01-08          NKE             nike       nike  Retail  Worldwide
# 2014-01-09          NKE             nike       nike  Retail  Worldwide
# 2014-01-10          NKE             nike       nike  Retail  Worldwide
# 2014-01-11          NKE             nike       nike  Retail  Worldwide
# 2014-01-12          NKE             nike       nike  Retail  Worldwide
# 2014-01-13          NKE             nike       nike  Retail  Worldwide
# 2014-01-14          NKE             nike       nike  Retail  Worldwide
# 2014-01-15          NKE             nike       nike  Retail  Worldwide
# 2014-01-16          NKE             nike       nike  Retail  Worldwide
# 2014-01-17          NKE             nike       nike  Retail  Worldwide
# 2014-01-18          NKE             nike       nike  Retail  Worldwide
# 2014-01-19          NKE             nike       nike  Retail  Worldwide
# 2014-01-20          NKE             nike       nike  Retail  Worldwide
#
#             followers_count  followees_count  posts_count  likes_count  \
# date
# 2014-01-01          3055602               69            1       197190
# 2014-01-02          3061505               69            1       199283
# 2014-01-03          3070820               70            0            0
# 2014-01-04          3078737               70            1       151875
# 2014-01-05          3086889               70            0            0
# 2014-01-06          3094587               70            2       299853
# 2014-01-07          3105772               70            0            0
# 2014-01-08          3113450               71            0            0
# 2014-01-09          3121689               71            1       185530
# 2014-01-10          3132240               71            1       169611
# 2014-01-11          3141723               71            0            0
# 2014-01-12          3150428               71            0            0
# 2014-01-13          3159276               71            0            0
# 2014-01-14          3170241               71            0            0
# 2014-01-15          3181184               72            1       142405
# 2014-01-16          3190771               72            0            0
# 2014-01-17          3191188               72            1       185267
# 2014-01-18          3191188               72            0            0
# 2014-01-19          3203029               72            1       188897
# 2014-01-20          3212850               72            0            0
#
#             comments_count  total_posts_count  engagement_score
# date
# 2014-01-01             840                648              1000
# 2014-01-02             827                648              1000
# 2014-01-03               0                649                 0
# 2014-01-04             412                649               999
# 2014-01-05               0                650                 0
# 2014-01-06            1491                650               998
# 2014-01-07               0                652                 0
# 2014-01-08               0                652                 0
# 2014-01-09             894                652              1000
# 2014-01-10             749                653               999
# 2014-01-11               0                654                 0
# 2014-01-12               0                654                 0
# 2014-01-13               0                654                 0
# 2014-01-14               0                654                 0
# 2014-01-15             485                654               997
# 2014-01-16               0                655                 0
# 2014-01-17            1090                655              1000
# 2014-01-18               0                655                 0
# 2014-01-19            3168                655              1000
# 2014-01-20               0                656                 0

# %% [markdown]
# Creating two new metrics to measure market sentiments towards Nike:

# %%
insta_sentiment['follower_growth'] = insta_sentiment['followers_count'].diff()

# %%
# Getting rid of irrelevant columns
more_cols_to_drop = ['brand_ticker', 'ins_account_name', 'brand_name', 'sector', 'geography', 'followees_count', 'posts_count', 'likes_count', 'comments_count', 'total_posts_count', 'engagement_score', 'followers_count']
insta_sentiment = insta_sentiment.drop(more_cols_to_drop, axis=1)
insta_sentiment.columns = ['insta_follower_growth']

# %%
insta_sentiment.head(5)
# Out:
#             insta_follower_growth
# date
# 2014-01-01                    NaN
# 2014-01-02                 5903.0
# 2014-01-03                 9315.0
# 2014-01-04                 7917.0
# 2014-01-05                 8152.0

# %% [markdown]
# ## Importing Stock Price Data

# %%
company_stock = quandl.get("WIKI/NKE")

# %%
no_rows = company_stock.shape[0]
no_columns = company_stock.shape[1]
print('The dimension of the Stock Price DataFrame is %s by %s' % (no_rows, no_columns))
# Out:
# The dimension of the Stock Price DataFrame is 9410 by 12

# %%
# Getting rid of irrelevant columns
even_more_cols_to_drop = ['Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
       'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Volume']
company_stock = company_stock.drop(even_more_cols_to_drop, axis=1)
company_stock['Adj_Close_Change'] = company_stock['Adj. Close'].diff()
company_stock.columns = ['stock_price', 'stock_price_change']

# %%
company_stock.head(5)
# Out:
#             stock_price  stock_price_change
# Date
# 1980-12-02     0.061535                 NaN
# 1980-12-03     0.060198           -0.001338
# 1980-12-04     0.062178            0.001980
# 1980-12-05     0.058860           -0.003318
# 1980-12-08     0.055542           -0.003318

# %%
company_stock.sort_index(inplace = True)
news_sentiments.sort_index(inplace = True)
facebook_sentiment.sort_index(inplace = True)
insta_sentiment.sort_index(inplace = True)

# %%
insta_sentiment.head(n=10)
# Out:
#             insta_follower_growth
# date
# 2014-01-01                    NaN
# 2014-01-02                 5903.0
# 2014-01-03                 9315.0
# 2014-01-04                 7917.0
# 2014-01-05                 8152.0
# 2014-01-06                 7698.0
# 2014-01-07                11185.0
# 2014-01-08                 7678.0
# 2014-01-09                 8239.0
# 2014-01-10                10551.0

# %% [markdown]
# ## Merging the Datasets Together

# %% [markdown]
# #### Note: Dataframes are merged by date

# %%
merge_1 = company_stock.join(news_sentiments, how = "left")

# %%
merge_1.tail()
# Out:
#             stock_price  stock_price_change ticker  sentiment  sentiment_high  \
# Date
# 2018-03-21        66.35               -0.45    NKE      1.794           3.245
# 2018-03-22        64.42               -1.93    NKE      0.286           2.833
# 2018-03-23        64.63                0.21    NKE      0.255           2.423
# 2018-03-26        65.90                1.27    NKE      1.313           3.541
# 2018-03-27        66.17                0.27    NKE      1.357           3.882
#
#             sentiment_low  news_volume  news_buzz
# Date
# 2018-03-21          0.343         34.0       10.0
# 2018-03-22         -3.262         56.0       10.0
# 2018-03-23         -2.913         94.0       10.0
# 2018-03-26         -1.916         32.0        7.0
# 2018-03-27         -2.167         14.0        1.0

# %%
#merge_2 = merge_1.join(facebook_sentiment, how = "left")
merge_3 = merge_1.join(insta_sentiment, how = "left")
merge_3['sentiment_growth'] = merge_3['sentiment'].diff()
# Out:
# (9410, 8)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-24bfe59391f8> in <module>()
#       4
#       5 print(merge_1.shape)
# ----> 6 print(merge_2.shape)
#       7 print(merge_3.shape)
#
# NameError: name 'merge_2' is not defined

# %%
merge_3.dropna(axis = 0, inplace = True)

# %%
merge_3.head(n = 10)
# Out:
#             stock_price  stock_price_change ticker  sentiment  sentiment_high  \
# Date
# 2014-01-02    37.419008           -0.191304    NKE      0.619           3.029
# 2014-01-03    37.318574           -0.100434    NKE      0.261           2.723
# 2014-01-06    37.031618           -0.286956    NKE      1.516           3.465
# 2014-01-07    37.060314            0.028696    NKE      1.313           3.052
# 2014-01-08    36.869010           -0.191304    NKE      0.220           2.510
# 2014-01-09    36.869010            0.000000    NKE      1.308           4.027
# 2014-01-10    36.787706           -0.081304    NKE      0.588           2.991
# 2014-01-13    35.955535           -0.832171    NKE      0.654           2.554
# 2014-01-14    35.950752           -0.004783    NKE      0.457           3.079
# 2014-01-15    36.075099            0.124347    NKE      1.846           3.878
#
#             sentiment_low  news_volume  news_buzz  insta_follower_growth  \
# Date
# 2014-01-02         -2.791         42.0       10.0                 5903.0
# 2014-01-03         -3.201         46.0       10.0                 9315.0
# 2014-01-06         -1.433         31.0       10.0                 7698.0
# 2014-01-07         -1.427         32.0        6.0                11185.0
# 2014-01-08         -3.071         41.0        8.0                 7678.0
# 2014-01-09         -2.411         39.0        8.0                 8239.0
# 2014-01-10         -2.814         51.0       10.0                10551.0
# 2014-01-13         -2.246         26.0       10.0                 8848.0
# 2014-01-14         -3.165         35.0        6.0                10965.0
# 2014-01-15         -1.186         26.0        5.0                10943.0
#
#             sentiment_growth
# Date
# 2014-01-02            -0.488
# 2014-01-03            -0.358
# 2014-01-06             1.255
# 2014-01-07            -0.203
# 2014-01-08            -1.093
# 2014-01-09             1.088
# 2014-01-10            -0.720
# 2014-01-13             0.066
# 2014-01-14            -0.197
# 2014-01-15             1.389

# %% [markdown]
# ### Modelling

# %%
data = merge_3.drop(["ticker"], axis = 1)

price = data["stock_price"]

# Length Hyperparameters
l_check = [5,20,120]

accuracies = []

# Choose Number of Features
cases = [1,8,9]

case = cases[2]

data = np.array(data.iloc[:,:case]) 

# Iterate Through Each Length
for j in range(len(l_check)):

    length = l_check[j]
    
    labels = np.zeros(((len(price) - length),1))

    count = 0

    for i in range((length-1),(len(price)-1)):
        if price[(i+1)] - price[(i)] > 0:
            labels[count] = 1
        else:
            labels[count] = 0

        count = count + 1   
       
    features = np.zeros((len(labels),length,case))
    
    for i in range(len(features)):

        features[i,:,:] = data[i:(i+length),:]

    arr = np.arange(0,int(features.shape[0]*0.7))
    arr2 = np.arange(int(features.shape[0]*0.7),features.shape[0])

    train_X = features[arr,:,:]
    train_Y = labels[arr,:]

    test_X = features[arr2,:,:]
    test_Y = labels[arr2,:]

    model = Sequential()
    model.add(LSTM(100, input_shape = (features.shape[1],case)))
    
    model.add(Dense(1, activation = "sigmoid"))

    opt = Adam(lr=0.02, beta_1=0.9, beta_2=0.999, decay=0.01)


    model.compile(loss='binary_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])

    model.fit(train_X, train_Y, epochs = 15)

    pred = model.predict(test_X)

    preds = np.zeros((len(pred),1))

    for i in range(len(pred)):
        if pred[i] > 0.5:
            preds[i] = 1
        else:
            preds[i] = 0

    accuracy = np.mean(preds == test_Y)
    
    accuracies.append(accuracy)
# Out:
# Epoch 1/15
# 742/742 [==============================] - 5s 6ms/step - loss: 0.6971 - acc: 0.5040
# Epoch 2/15
# 742/742 [==============================] - 1s 804us/step - loss: 0.7169 - acc: 0.4973
# Epoch 3/15
# 742/742 [==============================] - 1s 715us/step - loss: 0.6960 - acc: 0.5121
# Epoch 4/15
# 742/742 [==============================] - 1s 929us/step - loss: 0.6889 - acc: 0.5175
# Epoch 5/15
# 742/742 [==============================] - 1s 758us/step - loss: 0.6896 - acc: 0.5040
# Epoch 6/15
# 742/742 [==============================] - 1s 707us/step - loss: 0.6879 - acc: 0.4838
# Epoch 7/15
# 742/742 [==============================] - 1s 713us/step - loss: 0.6898 - acc: 0.4987
# Epoch 8/15
# 742/742 [==============================] - 1s 715us/step - loss: 0.6895 - acc: 0.5108
# Epoch 9/15
# 742/742 [==============================] - 1s 719us/step - loss: 0.6900 - acc: 0.4933
# Epoch 10/15
# 742/742 [==============================] - 1s 713us/step - loss: 0.6875 - acc: 0.4811
# Epoch 11/15
# 742/742 [==============================] - 1s 718us/step - loss: 0.6889 - acc: 0.5000
# Epoch 12/15
# 742/742 [==============================] - 1s 709us/step - loss: 0.6868 - acc: 0.5216
# Epoch 13/15
# 742/742 [==============================] - 1s 716us/step - loss: 0.6858 - acc: 0.5121
# Epoch 14/15
# 742/742 [==============================] - 1s 742us/step - loss: 0.6860 - acc: 0.5216
# Epoch 15/15
# 742/742 [==============================] - 1s 714us/step - loss: 0.6859 - acc: 0.5216
# Epoch 1/15
# 731/731 [==============================] - 5s 6ms/step - loss: 0.6985 - acc: 0.5185
# Epoch 2/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6929 - acc: 0.5267
# Epoch 3/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.7221 - acc: 0.5062
# Epoch 4/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.7013 - acc: 0.5130
# Epoch 5/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6937 - acc: 0.5130
# Epoch 6/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6913 - acc: 0.5267
# Epoch 7/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6974 - acc: 0.4938
# Epoch 8/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6912 - acc: 0.5034
# Epoch 9/15
# 731/731 [==============================] - 2s 3ms/step - loss: 0.6915 - acc: 0.5171
# Epoch 10/15
# 731/731 [==============================] - 3s 5ms/step - loss: 0.6906 - acc: 0.5021
# Epoch 11/15
# 731/731 [==============================] - 3s 4ms/step - loss: 0.6897 - acc: 0.5267
# Epoch 12/15
# 731/731 [==============================] - 3s 4ms/step - loss: 0.6912 - acc: 0.4952
# Epoch 13/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6913 - acc: 0.5157
# Epoch 14/15
# 731/731 [==============================] - 2s 2ms/step - loss: 0.6905 - acc: 0.5171
# Epoch 15/15
# 731/731 [==============================] - 3s 4ms/step - loss: 0.6909 - acc: 0.5075
# Epoch 1/15
# 661/661 [==============================] - 15s 23ms/step - loss: 0.7177 - acc: 0.5008
# Epoch 2/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.7023 - acc: 0.4766
# Epoch 3/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6936 - acc: 0.5083
# Epoch 4/15
# 661/661 [==============================] - 15s 22ms/step - loss: 0.6952 - acc: 0.5008
# Epoch 5/15
# 661/661 [==============================] - 16s 24ms/step - loss: 0.6933 - acc: 0.5129
# Epoch 6/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6943 - acc: 0.4766
# Epoch 7/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6936 - acc: 0.5234
# Epoch 8/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6974 - acc: 0.4841
# Epoch 9/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6960 - acc: 0.4962
# Epoch 10/15
# 661/661 [==============================] - 15s 22ms/step - loss: 0.6906 - acc: 0.5068
# Epoch 11/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6926 - acc: 0.4947
# Epoch 12/15
# 661/661 [==============================] - 19s 29ms/step - loss: 0.6979 - acc: 0.5053
# Epoch 13/15
# 661/661 [==============================] - 20s 31ms/step - loss: 0.6909 - acc: 0.4811
# Epoch 14/15
# 661/661 [==============================] - 15s 23ms/step - loss: 0.6913 - acc: 0.4992
# Epoch 15/15
# 661/661 [==============================] - 14s 21ms/step - loss: 0.6897 - acc: 0.5113

# %%
accuracies
# Out:
# [0.46540880503144655, 0.535031847133758, 0.5633802816901409]

# %% [markdown]
# ## Accuracy Results

# %%
Week = [0.525, 0.525, 0.465]
Month = [0.465,0.497,0.528]
Month_6 = [0.465,0.535,0.563]


df = pd.DataFrame([Price, Price_Sentiment, Price_Sentiment_Growth])

df.columns = ["Week", "Month", "6-Month"]

df.index = ["Price", "Price_Sentiment", "Price_Sentiment_Growth"]

df.head()
# Out:
#                          Week  Month  6-Month
# Price                   0.525  0.525    0.465
# Price_Sentiment         0.465  0.497    0.528
# Price_Sentiment_Growth  0.465  0.535    0.563
